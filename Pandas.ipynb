# %% [markdown]
# ###Pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
dados = {'Estado':['Santa Catarina','Rio de Janeiro', 'Tocantins', 'Bahia', 'Minas Gerais'],
         'Ano': [2004, 2005, 2006, 2007, 2008],
         'Taxa Desemprego':[1.5, 1.7, 1.6, 2.4, 2.7]
         }

# %%
df = pd.DataFrame(dados)

# %%
df.head()
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2       Tocantins  2006              1.6
# 3           Bahia  2007              2.4
# 4    Minas Gerais  2008              2.7

# %%
#Mostra tipos, campos nulos e nomes das coluna, muito util
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Estado           5 non-null      object
#  1   Ano              5 non-null      int64
#  2   Taxa Desemprego  5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df1 = pd.DataFrame(dados, columns=['Estado', 'Taxa Desemprego', 'Taxa Crescimento', 'Ano'],
                   index=['estado1', 'estado2','estado3', 'estado4', 'estado5'])

# %%
df1
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5              NaN  2004
# estado2  Rio de Janeiro              1.7              NaN  2005
# estado3       Tocantins              1.6              NaN  2006
# estado4           Bahia              2.4              NaN  2007
# estado5    Minas Gerais              2.7              NaN  2008

# %%
df1['Estado']
# Out:
# estado1    Santa Catarina
# estado2    Rio de Janeiro
# estado3         Tocantins
# estado4             Bahia
# estado5      Minas Gerais
# Name: Estado, dtype: object

# %% [markdown]
# ss

# %% [markdown]
# Mostra dados estatísticos sobre o dataframe

# %%
df1.describe()
# Out:
#        Taxa Desemprego          Ano
# count         5.000000     5.000000
# mean          1.980000  2006.000000
# std           0.535724     1.581139
# min           1.500000  2004.000000
# 25%           1.600000  2005.000000
# 50%           1.700000  2006.000000
# 75%           2.400000  2007.000000
# max           2.700000  2008.000000

# %% [markdown]
# Dtypes mostra o tipo dos dados, mas o metodo info é mais completo

# %%
df1.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento     object
# Ano                   int64
# dtype: object

# %%
df1.isna()
# Out:
#          Estado  Taxa Desemprego  Taxa Crescimento    Ano
# estado1   False            False              True  False
# estado2   False            False              True  False
# estado3   False            False              True  False
# estado4   False            False              True  False
# estado5   False            False              True  False

# %%
df1['Taxa Crescimento'] = np.arange(5.)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Estado           5 non-null      object
#  1   Ano              5 non-null      int64
#  2   Taxa Desemprego  5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df1
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007
# estado5    Minas Gerais              2.7               4.0  2008

# %%
df1['estado2':'estado4']
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007

# %%
df1[df1['Estado'] == 'Minas Gerais']
# Out:
#                Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado5  Minas Gerais              2.7               4.0  2008

# %% [markdown]
# Inserindo dados em colunas

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9994 non-null   object
#  1   Data_Pedido   9994 non-null   object
#  2   ID_Cliente    9994 non-null   object
#  3   Segmento      9994 non-null   object
#  4   Pais          9994 non-null   object
#  5   Regiao        9994 non-null   object
#  6   ID_Produto    9994 non-null   object
#  7   Categoria     9994 non-null   object
#  8   Nome_Produto  9994 non-null   object
#  9   Valor_Venda   9994 non-null   float64
#  10  Quantidade    9992 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 859.0+ KB

# %%
dataset.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
dataset['Quantidade']
# Out:
# 0       NaN
# 1       NaN
# 2       2.0
# 3       5.0
# 4       2.0
#        ...
# 9989    3.0
# 9990    2.0
# 9991    2.0
# 9992    4.0
# 9993    2.0
# Name: Quantidade, Length: 9994, dtype: float64

# %%
mode = dataset['Quantidade'].value_counts().index[0]
print(mode)
# Out:
# 3.0

# %%
dataset.iloc[2408]
# Out:
# ID_Pedido                                          CA-2017-144589
# Data_Pedido                                            2017-01-20
# ID_Cliente                                               TM-21010
# Segmento                                                 Consumer
# Pais                                                United States
# Regiao                                                       West
# ID_Produto                                        TEC-PH-10003072
# Categoria                                              Technology
# Nome_Produto    Panasonic KX-TG9541B DECT 6.0 Digital 2-Line E...
# Valor_Venda                                               359.976
# Quantidade                                                    3.0
# Name: 2408, dtype: object

# %%
dataset['Quantidade'].fillna(value= mode, inplace=True)
dataset.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %%
dataset
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2     CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# ...              ...         ...        ...        ...            ...    ...
# 9989  CA-2014-110422  2014-01-21   TB-21400   Consumer  United States  South
# 9990  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9991  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9992  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9993  CA-2017-119914  2017-05-04   CC-12220   Consumer  United States   West
#
#            ID_Produto        Categoria  \
# ...

# %% [markdown]
# ##Query

# %%
dataset.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
valor_entre300_e_1000 = dataset.query('229 < Valor_Venda < 10000')

# %%
valor_entre300_e_1000.Valor_Venda.describe()
# Out:
# count    2357.000000
# mean      766.679142
# std       856.315136
# min       229.544000
# 25%       323.100000
# 50%       490.320000
# 75%       859.200000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %%
maior_que_766 = dataset.query('Valor_Venda > 766')

# %%
maior_que_766['Valor_Venda'].describe()
# Out:
# count      692.000000
# mean      1713.517382
# std       1703.514752
# min        767.214000
# 25%        915.094500
# 50%       1216.744000
# 75%       1793.980000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# Aqui abaixo estamos verificando se a coluna Quantidade tem os valores 5,7,9,11

# %%
dataset[dataset['Quantidade'].isin([5,7,9,11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# ...

# %%
dataset[(dataset.Segmento != 'Home Office') & (dataset.Regiao != 'South')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 5  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 6  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 7  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 8  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 2  OFF-LA-10000240  Office Supplies
# 5  FUR-FU-10001487        Furniture
# 6  OFF-AR-10002833  Office Supplies
# 7  TEC-PH-10002275       Technology
# 8  OFF-BI-10003910  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 2  Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       48.860         7.0
# ...

# %%
dataframe_with_query1 = dataset.query('Segmento != "Home Office" and Regiao != "South"').head()
dataframe_with_query1
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 5  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 6  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 7  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
# 8  CA-2014-115812  2014-06-09   BH-11710   Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 2  OFF-LA-10000240  Office Supplies
# 5  FUR-FU-10001487        Furniture
# 6  OFF-AR-10002833  Office Supplies
# 7  TEC-PH-10002275       Technology
# 8  OFF-BI-10003910  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 2  Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       48.860         7.0
# ...

# %%
dataset[(dataset.Segmento == 'Home Office') | (dataset.Regiao == 'South')].tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 9979   West  OFF-BI-10002026  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 9979                  Ibico Recycled Linen-Style Covers      437.472
# 9980                         KI Adjustable-Height Table       85.980
# ...

# %%
dataframe_with_query2 = dataset.query('Segmento != "Home Office" or Regiao != "South"').sample(5)
dataframe_with_query2
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 5371  US-2017-136721  2017-04-08   NH-18610  Corporate  United States
# 219   CA-2015-169397  2015-12-24   JB-15925   Consumer  United States
# 5181  CA-2017-108749  2017-09-12   DJ-13510  Corporate  United States
# 2347  CA-2016-159373  2016-03-13   LT-17110   Consumer  United States
# 8666  CA-2016-163951  2016-12-30   CJ-11875  Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 5371  Central  FUR-FU-10004188        Furniture
# 219      East  OFF-FA-10000585  Office Supplies
# 5181     East  OFF-PA-10003797  Office Supplies
# 2347  Central  FUR-TA-10004619        Furniture
# 8666     East  OFF-AR-10004269  Office Supplies
#
#                                       Nome_Produto  Valor_Venda  Quantidade
# 5371  Luxo Professional Combination Clamp-On Lamps      306.900         3.0
# 219               OIC Bulk Pack Metal Binder Clips        5.584         2.0
# ...

# %%
dataset[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento','Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %%
dataset[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento','Regiao']).agg(['mean','std', 'count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571

# %%
dataset[dataset.Segmento.str.startswith('Con')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dataset[dataset.Segmento.str.endswith('mer')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9994 non-null   object
#  1   Data_Pedido   9994 non-null   object
#  2   ID_Cliente    9994 non-null   object
#  3   Segmento      9994 non-null   object
#  4   Pais          9994 non-null   object
#  5   Regiao        9994 non-null   object
#  6   ID_Produto    9994 non-null   object
#  7   Categoria     9994 non-null   object
#  8   Nome_Produto  9994 non-null   object
#  9   Valor_Venda   9994 non-null   float64
#  10  Quantidade    9994 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 859.0+ KB

# %%
#mudando data para 2 digitos
dataset['Data_Pedido'].str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %%
dataset.head(3)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase       261.96         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       731.94         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...        14.62         2.0

# %%
df_copy = dataset.copy()

# %%
df_copy['ID_Cliente'] = df_copy['ID_Cliente'].str.replace('CG', 'AX')

# %%
df_copy.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
df_copy['Pedido_Segmento'] = df_copy['ID_Pedido'].str.cat(df_copy['Segmento'], sep='-')
df_copy.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
lista = [1,2,3,3,4,5,6,6]
def count_function(array, element_to_compare):
  count = 0
  for element in array:
    if element_to_compare == element:
      count += 1
  return count

data = {i: count_function(lista, i) for i in lista}
data
# Out:
# {1: 1, 2: 1, 3: 2, 4: 1, 5: 1, 6: 2}

# %%
sorted_list = sorted([1,2,3,9,6,8])
center_position = len(sorted_list) // 2
print(sorted_list, center_position)
# Out:
# [1, 2, 3, 6, 8, 9] 3

# %%
if len(sorted_list) % 2 == 0:
    resultado =(sorted_list[center_position] + sorted_list[center_position - 1]) / 2

# %%
resultado
# Out:
# 4.5

# %%
lista = [10,32,22,56,98, 98]
maximo = 98
res = list(filter(lambda key: lista[key] == maximo, range(len(lista))))

# %%
res
# Out:
# [4, 5]

# %%
arr = [1,9,55,62,78,23,5,44]
maior = arr[0]
for element in arr:
  if maior < element:
    maior = element

# %%
maior
# Out:
# 78
